# %% [markdown]
# <a href="https://colab.research.google.com/github/runfuture/RKNN-colab/blob/main/rknn_toolkit2_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #RKNN-Toolkit2 Notebook
# To try running the examples of RKNN-Toolkit2 in Colab. It's a fast way to become familiar with the tool for building models that are intended to run on Rockchip NPU.

# %% [markdown]
# # Install ONNX

# %% [markdown]
# # Intall torch and torchvision (only for convert pytorch model)

# %%
# !pip install torch==1.13.1
# !pip install torchvision==0.14.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 66.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 67.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.13.1 which is incompatible.
# ...

# %%
# !pip install onnx==1.14.0
# !pip install onnxoptimizer==0.3.8
# !pip install onnxruntime==1.14.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 74.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 647.2/647.2 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 39.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 184.0 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 4.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Get the latest RKNN-Toolkit2 (v1.5.2)

# %%
# %cd /content
# !git clone -b v1.5.2 --depth 1 https://github.com/airockchip/rknn-toolkit2
# %cd rknn-toolkit2
# Out:
# /content
# Cloning into 'rknn-toolkit2'...
# remote: Enumerating objects: 193, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (151/151), done.
# remote: Total 193 (delta 34), reused 182 (delta 29), pack-reused 0
# Receiving objects: 100% (193/193), 311.28 MiB | 42.67 MiB/s, done.
# Resolving deltas: 100% (34/34), done.
# Updating files: 100% (168/168), done.
# /content/rknn-toolkit2

# %% [markdown]
# # Install RKNN-Toolkit2

# %%
# !pip install --no-deps /content/rknn-toolkit2/packages/rknn_toolkit2-1.5.2+b642f30c-cp310-cp310-linux_x86_64.whl
# !pip install ruamel.yaml
# Out:
# Processing ./packages/rknn_toolkit2-1.5.2+b642f30c-cp310-cp310-linux_x86_64.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.9/112.9 kB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 21.4 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# rknn-toolkit2 1.5.2+b642f30c requires fast-histogram==0.11, which is not installed.
# rknn-toolkit2 1.5.2+b642f30c requires flatbuffers==2.0, but you have flatbuffers 23.5.26 which is incompatible.
# rknn-toolkit2 1.5.2+b642f30c requires numpy==1.23.4, but you have numpy 1.23.5 which is incompatible.
# rknn-toolkit2 1.5.2+b642f30c requires opencv-python==4.5.5.64, but you have opencv-python 4.8.0.76 which is incompatible.
# rknn-toolkit2 1.5.2+b642f30c requires psutil==5.9.0, but you have psutil 5.9.5 which is incompatible.
# ...

# %% [markdown]
# # Caffe model to RKNN

# %%
# %cd /content/rknn-toolkit2/examples/caffe/mobilenet_v2
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/caffe/mobilenet_v2
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# W config: The quant_img_RGB2BGR of input 0 is set to True, which means that the RGB2BGR conversion will be done first
#           when the quantized image is loaded (only valid for jpg/jpeg/png/bmp, npy will ignore this flag).
#           Special note here, if quant_img_RGB2BGR is True and the quantized image is jpg/jpeg/png/bmp,
#           the mean_values / std_values in the config corresponds the order of BGR.
# done
# --> Loading model
# Loading : 100%|██████████████████████████████████████████████████| 267/267 [00:00<00:00, 644.58it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# I fuse_ops results:
# ...

# %%
# %cd /content/rknn-toolkit2/examples/caffe/vgg-ssd
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/caffe/vgg-ssd
# !!! Missing VGG_VOC0712_SSD_300x300_iter_120000.caffemodel !!!
# 1. Download models_VGGNet_VOC0712_SSD_300x300.tar.gz from https://drive.google.com/file/d/0BzKzrI_SkD1_WVVTSmQxU0dVRzA/view
# 2. Extract the VGG_VOC0712_SSD_300x300_iter_120000.caffemodel from models_VGGNet_VOC0712_SSD_300x300.tar.gz
# 3. Or you can also download caffemodel from https://eyun.baidu.com/s/3jJhPRzo , password is rknn

# %% [markdown]
# # Darknet/YOLO model to RKNN

# %%
# %cd /content/rknn-toolkit2/examples/darknet/yolov3_416x416
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/darknet/yolov3_416x416
# ...
# Download yolov3.weight success.
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# skipping yolo node generation.
# skipping yolo node generation.
# skipping yolo node generation.
# Loading : 100%|███████████████████████████████████████████████████| 368/368 [00:07<00:00, 51.04it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# I fuse_ops results:
# ...

# %% [markdown]
# To show the result:

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = "./result.jpg"
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# # ONNX Models -> RKNN

# %% [markdown]
# Resnet50v2:

# %%
# %cd /content/rknn-toolkit2/examples/onnx/resnet50v2
# !python test.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 63.97%  [################################------------------] Speed: 30.18 MB/s
# 63.98%  [################################------------------] Speed: 30.18 MB/s
# 63.99%  [################################------------------] Speed: 30.19 MB/s
# 64.00%  [################################------------------] Speed: 30.19 MB/s
# 64.01%  [################################------------------] Speed: 30.19 MB/s
# 64.01%  [################################------------------] Speed: 30.20 MB/s
# 64.02%  [################################------------------] Speed: 30.20 MB/s
# 64.03%  [################################------------------] Speed: 30.20 MB/s
# 64.04%  [################################------------------] Speed: 30.21 MB/s
# 64.05%  [################################------------------] Speed: 30.21 MB/s
# 64.05%  [################################------------------] Speed: 30.21 MB/s
# ...

# %% [markdown]
# YOLOv5:

# %%
# %cd /content/rknn-toolkit2/examples/onnx/yolov5
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/onnx/yolov5
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# Loading : 100%|████████████████████████████████████████████████| 125/125 [00:00<00:00, 11030.91it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# W build: Resize [Resize_88] convert to Deconvolution for inference speedup, but may cause result driftting.
# To disable this optimization, please set 'optimization_level = 2' in 'rknn.config'
# I fuse_ops results:
# I     convert_resize_to_deconv: remove node = ['Resize_88'], add node = ['Resize_88_2deconv']
# W build: Resize [Resize_104] convert to Deconvolution for inference speedup, but may cause result driftting.
# To disable this optimization, please set 'optimization_level = 2' in 'rknn.config'
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = "./result.jpg"
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# # Tensorflow Models -> RKNN

# %% [markdown]
# InceptionV3 QAT:

# %%
# %cd /content/rknn-toolkit2/examples/tensorflow/inception_v3_qat
# !python test.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 82.82%  [#########################################---------] Speed: 32.98 MB/s
# 82.82%  [#########################################---------] Speed: 32.98 MB/s
# 82.83%  [#########################################---------] Speed: 32.98 MB/s
# 82.83%  [#########################################---------] Speed: 32.98 MB/s
# 82.83%  [#########################################---------] Speed: 32.98 MB/s
# 82.84%  [#########################################---------] Speed: 32.98 MB/s
# 82.84%  [#########################################---------] Speed: 32.98 MB/s
# 82.85%  [#########################################---------] Speed: 32.99 MB/s
# 82.85%  [#########################################---------] Speed: 32.99 MB/s
# 82.85%  [#########################################---------] Speed: 32.99 MB/s
# 82.86%  [#########################################---------] Speed: 32.99 MB/s
# ...

# %% [markdown]
# MobileNetV1-SSD:

# %%
# %cd /content/rknn-toolkit2/examples/tensorflow/ssd_mobilenet_v1
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/tensorflow/ssd_mobilenet_v1
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# 2023-10-11 07:36:06.825168: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-11 07:36:07.973510: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# W load_tensorflow: The inputs name should be a tensor name instead of node name
# W:tensorflow:From /usr/local/lib/python3.10/dist-packages/rknn/api/rknn.py:132: convert_variables_to_constants (from tensorflow.python.framework.convert_to_constants) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

image_path = "result.jpg"
image = Image.open(image_path)
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
# # TFLite Models -> RKNN

# %% [markdown]
# MobileNetV1:

# %%
# %cd /content/rknn-toolkit2/examples/tflite/mobilenet_v1
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/tflite/mobilenet_v1
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# 2023-10-11 07:36:53.631180: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-11 07:36:54.801379: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Error loading model into tflite interpreter: Interpreter._get_tensor_details() missing 1 required positional argument: 'subgraph_index'
# Loading : 100%|███████████████████████████████████████████████████| 58/58 [00:00<00:00, 6925.04it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# ...

# %% [markdown]
# MobileNetV1 QAT:

# %%
# %cd /content/rknn-toolkit2/examples/tflite/mobilenet_v1_qat/
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/tflite/mobilenet_v1_qat
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# 2023-10-05 16:20:30.113019: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 16:20:31.733675: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# Error loading model into tflite interpreter: Interpreter._get_tensor_details() missing 1 required positional argument: 'subgraph_index'
# W load_tflite: The current config.optimization_level = 3, some optimize passes will case accuracy changes,
# ...

# %% [markdown]
# # Pytorch Models -> RKNN

# %% [markdown]
# Resnet18:

# %%
# %cd /content/rknn-toolkit2/examples/pytorch/resnet18
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/pytorch/resnet18
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 62.7MB/s]
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# ...

# %% [markdown]
# Resnet18 to ONNX:

# %%
# %cd /content/rknn-toolkit2/examples/pytorch/resnet18_export_onnx/
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/pytorch/resnet18_export_onnx

# %%
# %ls
# Out:
# README.md  resnet18.onnx  test.py

# %% [markdown]
# Resnet18 QAT:

# %%
# %cd /content/rknn-toolkit2/examples/pytorch/resnet18_qat/
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/pytorch/resnet18_qat
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# Loading : 100%|██████████████████████████████████████████████████| 182/182 [00:01<00:00, 118.02it/s]
# W load_pytorch: The current config.optimization_level = 3, some optimize passes will case accuracy changes,
#                               If you want consistent accuracy, you can set config.optimization_level = 2 to disable these passes!
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I quant_optimizer ...
# I quant_optimizer done.
# I
# I quant_optimizer ...
# I quant_optimizer done.
# I
# W build: The 'scale' of 'conv1_weight' has been adjusted by hardware limit at rk3566/rk3568 in QAT model, may case results to vary!
# I fuse_ops ...
# I fuse_ops results:
# ...

# %% [markdown]
# # Feature Tests

# %% [markdown]
# ## Accuracy analysis

# %%
# %cd /content/rknn-toolkit2/examples/functions/accuracy_analysis/
# !python test.py
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# 65.24%  [#################################-----------------] Speed: 10.79 MB/s
# 65.25%  [#################################-----------------] Speed: 10.79 MB/s
# 65.26%  [#################################-----------------] Speed: 10.79 MB/s
# 65.27%  [#################################-----------------] Speed: 10.79 MB/s
# 65.28%  [#################################-----------------] Speed: 10.80 MB/s
# 65.28%  [#################################-----------------] Speed: 10.80 MB/s
# 65.29%  [#################################-----------------] Speed: 10.80 MB/s
# 65.30%  [#################################-----------------] Speed: 10.80 MB/s
# 65.31%  [#################################-----------------] Speed: 10.80 MB/s
# 65.32%  [#################################-----------------] Speed: 10.80 MB/s
# 65.32%  [#################################-----------------] Speed: 10.80 MB/s
# ...

# %% [markdown]
# ## Quantization using MMSE algorithm

# %%
# %cd /content/rknn-toolkit2/examples/functions/mmse
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/functions/mmse
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# 2023-10-05 16:39:03.762499: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 16:39:04.967391: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# W load_tensorflow: The inputs name should be a tensor name instead of node name
# W:tensorflow:From /usr/local/lib/python3.10/dist-packages/rknn/api/rknn.py:132: convert_variables_to_constants (from tensorflow.python.framework.convert_to_constants) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %% [markdown]
# ## Hybrid Quantization

# %%
# %cd /content/rknn-toolkit2/examples/functions/hybrid_quant/
# !python step1.py
# Out:
# /content/rknn-toolkit2/examples/functions/hybrid_quant
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# done
# --> Loading model
# 2023-10-05 16:34:26.699546: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 16:34:27.895801: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# W load_tensorflow: The inputs name should be a tensor name instead of node name
# W:tensorflow:From /usr/local/lib/python3.10/dist-packages/rknn/api/rknn.py:132: convert_variables_to_constants (from tensorflow.python.framework.convert_to_constants) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...

# %%
# %cat ssd_mobilenet_v2.quantization.cfg
# Out:
# custom_quantize_layers:
#     Conv__350:0: float16
#     Conv__351:0: float16
#     FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/BatchNorm/batchnorm/add_1:0: float16
#     FeatureExtractor/MobilenetV2/expanded_conv_1/depthwise/Relu6:0: float16
#     Conv__358:0: float16
#     FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/BatchNorm/batchnorm/add_1:0: float16
#     FeatureExtractor/MobilenetV2/expanded_conv_2/depthwise/Relu6:0: float16
#     FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/BatchNorm/batchnorm/add_1:0: float16
#     FeatureExtractor/MobilenetV2/expanded_conv_13/depthwise/Relu6:0: float16
#     Conv__489:0: float16
#     BoxPredictor_5/BoxEncodingPredictor/BiasAdd:0: float16
#     concat_swap_concat_reshape_i5_out: float16
#     concat_swap_concat_reshape_o0_out: float16
#     BoxPredictor_0/BoxEncodingPredictor/BiasAdd:0: float16
#     BoxPredictor_0/BoxEncodingPredictor/BiasAdd__341:0: float16
#     concat_swap_concat_reshape_i0_out: float16
# ...

# %%
# !python step2.py
# Out:
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> hybrid_quantization_step2
# Loading : 100%|█████████████████████████████████████████████████| 260/260 [00:00<00:00, 4087.85it/s]
# I fuse_ops ...
# I fuse_ops done.
# I
# I quant_optimizer ...
# I quant_optimizer done.
# I
# I quantized_algorithm is normal, skip re-quantization!
# W hybrid_quantization_step2: The default input dtype of 'FeatureExtractor/MobilenetV2/MobilenetV2/input:0' is changed from 'float32' to 'int8' in rknn model for performance!
#                        Please take care of this change when deploy rknn model with Runtime API!
# W hybrid_quantization_step2: The default output dtype of 'concat_1:0' is changed from 'float32' to 'int8' in rknn model for performance!
#                       Please take care of this change when deploy rknn model with Runtime API!
# W hybrid_quantization_step2: The default output dtype of 'concat:0' is changed from 'float32' to 'int8' in rknn model for performance!
# ...

# %% [markdown]
# ## Model pruning

# %%
# %cd /content/rknn-toolkit2/examples/functions/model_pruning/
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/functions/model_pruning
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# W config: The quant_img_RGB2BGR of input 0 is set to True, which means that the RGB2BGR conversion will be done first
#           when the quantized image is loaded (only valid for jpg/jpeg/png/bmp, npy will ignore this flag).
#           Special note here, if quant_img_RGB2BGR is True and the quantized image is jpg/jpeg/png/bmp,
#           the mean_values / std_values in the config corresponds the order of BGR.
# done
# --> Loading model
# Loading : 100%|██████████████████████████████████████████████████| 137/137 [00:00<00:00, 325.68it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# I fuse_ops results:
# ...

# %% [markdown]
# ## C++ deploy code auto generation

# %%
# %cd /content/rknn-toolkit2/examples/functions/gen_cpp_rknn_deploy_demo/
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/functions/gen_cpp_rknn_deploy_demo
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# W config: The quant_img_RGB2BGR of input 0 is set to True, which means that the RGB2BGR conversion will be done first
#           when the quantized image is loaded (only valid for jpg/jpeg/png/bmp, npy will ignore this flag).
#           Special note here, if quant_img_RGB2BGR is True and the quantized image is jpg/jpeg/png/bmp,
#           the mean_values / std_values in the config corresponds the order of BGR.
# done
# --> Loading model
# Loading : 100%|██████████████████████████████████████████████████| 267/267 [00:00<00:00, 662.58it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# I fuse_ops results:
# ...

# %% [markdown]
# ## Multiple inputs model

# %%
# %cd /content/rknn-toolkit2/examples/functions/multi_input_test/
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/functions/multi_input_test
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# /usr/local/lib/python3.10/dist-packages/rknn/api/rknn.py:120: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return self.rknn_base.config(args)
# done
# --> Loading model
# 2023-10-03 06:26:43.276059: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-03 06:26:44.185034: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %% [markdown]
# ## Multiple Batch

# %%
# %cd /content/rknn-toolkit2/examples/functions/batch_size
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/functions/batch_size
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# W config: The quant_img_RGB2BGR of input 0 is set to True, which means that the RGB2BGR conversion will be done first
#           when the quantized image is loaded (only valid for jpg/jpeg/png/bmp, npy will ignore this flag).
#           Special note here, if quant_img_RGB2BGR is True and the quantized image is jpg/jpeg/png/bmp,
#           the mean_values / std_values in the config corresponds the order of BGR.
# done
# --> Loading model
# Loading : 100%|██████████████████████████████████████████████████| 267/267 [00:00<00:00, 697.21it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# I fuse_ops results:
# ...

# %% [markdown]
# ## Dynamic input (dynamic shape)

# %%
# %cd /content/rknn-toolkit2/examples/functions/dynamic_input/
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/functions/dynamic_input
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# W config: The quant_img_RGB2BGR of input 0 is set to True, which means that the RGB2BGR conversion will be done first
#           when the quantized image is loaded (only valid for jpg/jpeg/png/bmp, npy will ignore this flag).
#           Special note here, if quant_img_RGB2BGR is True and the quantized image is jpg/jpeg/png/bmp,
#           the mean_values / std_values in the config corresponds the order of BGR.
# W config: Please make sure the model can be dynamic when enable 'config.dynamic_input'!
# done
# --> Loading model
# Loading : 100%|██████████████████████████████████████████████████| 267/267 [00:00<00:00, 663.75it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# I fuse_ops results:
# ...

# %% [markdown]
# ## Board test - **Can't work on Colab obviously**

# %%
# %cd /content/rknn-toolkit2/examples/functions/board_test
# !python test.py
# Out:
# /content/rknn-toolkit2/examples/functions/board_test
# W __init__: rknn-toolkit2 version: 1.5.2+b642f30c
# --> Config model
# W config: The quant_img_RGB2BGR of input 0 is set to True, which means that the RGB2BGR conversion will be done first
#           when the quantized image is loaded (only valid for jpg/jpeg/png/bmp, npy will ignore this flag).
#           Special note here, if quant_img_RGB2BGR is True and the quantized image is jpg/jpeg/png/bmp,
#           the mean_values / std_values in the config corresponds the order of BGR.
# done
# --> Loading model
# Loading : 100%|██████████████████████████████████████████████████| 267/267 [00:00<00:00, 698.63it/s]
# done
# --> Building model
# I base_optimize ...
# I base_optimize done.
# I
# I fold_constant ...
# I fold_constant done.
# I
# I correct_ops ...
# I correct_ops done.
# I
# I fuse_ops ...
# I fuse_ops results:
# ...
